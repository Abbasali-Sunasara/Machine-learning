# %%
class Stack:
    def __init__(self):
        self.items = []

    def is_empty(self):
        return len(self.items)==0

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items[-1]
        return None

class TreeNode:
    def __init__(self, NewData = None, 1child = None, rchild = None):
        self.left = 1child
        self.data = NewData
        self.right  = rchild

class BST:
    def __init__(self):
        self.root = None

    def insert(self,NewData):
        newNode = TreeNode(NewData)
        if self.root is None:
            self.root = newNode
        else:
            curNode = self.root
            parentNode = None
            while curNode is not None:
                parentNode = curNode
                if NewData < curNode.data:
                    curNode = curNode.left
                else:
                    curNode = curNode.right
            
            if newData < parentNode.data:
                parentNode.left = newNode
            else:
                parentNode.right = newNode

    def preorder(self):
        st = Stack()
        curNode = self.root
        while curNode is not None:
            print(curNode)
            curNode = curNode.left
        curNode = st.pop()
        printss
