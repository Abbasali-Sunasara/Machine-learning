# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data = [0.5,10,12,14,11,13,100,12,15,14,11,200,400]
mean = np.mean(data)
mean
# Out:
# 62.5

# %%
std = np.std(mean)

# %%
std
# Out:
# 0.0

# %%
threshold = 3
outlier = [x for x in data if (x-mean) / std >  threshold]
outlier
# Out:
# [100, 200, 400]

# %%
data = {'Sales': [100, 120, 130, 115, 105, 500, 110, 95, 98, 102, 108, 107, 125, 600]}
df = pd.DataFrame(data)

Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)
IQR = Q3 - Q1  

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Sales'] < lower_bound) | (df['Sales'] > upper_bound)]
print("Outliers:\n", outliers)

df_cleaned = df[(df['Sales'] >= lower_bound) & (df['Sales'] <= upper_bound)]
print("\nCleaned Data:\n", df_cleaned)

plt.boxplot(df)
plt.show()
# Out:
# Outliers:
#      Sales
# 5     500
# 13    600
#
# Cleaned Data:
#      Sales
# 0     100
# 1     120
# 2     130
# 3     115
# 4     105
# 6     110
# 7      95
# 8      98
# 9     102
# 10    108
# 11    107
# 12    125
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 17
#      14 df_cleaned = df[(df['Sales'] >= lower_bound) & (df['Sales'] <= upper_bound)]
#      15 print("\nCleaned Data:\n", df_cleaned)
# ---> 17 plt.boxplot(df)
#      18 plt.show()
#
# NameError: name 'plt' is not defined
