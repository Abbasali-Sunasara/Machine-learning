# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Files/house_prices.csv')
df
# Out:
#    House Size  House Price
# 0        1500       350000
# 1        1800       400000
# 2        2000       450000
# 3        2200       475000
# 4        2500       525000
# 5        2800       575000
# 6        3000       600000
# 7        3200       650000
# 8        3500       700000
# 9        4000       750000

# %%
x = df ['House Size' ].values.reshape (-1,1)
y = df['House Price'].values

# %%
X_train,X_test, Y_train, Y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([682945.16509434, 410804.83490566])

# %%
Y_test
# Out:
# array([700000, 400000], dtype=int64)

# %%
data={'A':[1200,1500,2000,2500,3000,3200,4000]}
df = pd.DataFrame(data)
x = df['A'].values.reshape(-1,1) #-1(row) means it is dynamically change on the number of data#
print(x.shape)
print(x)
# Out:
# (7, 1)
# [[1200]
#  [1500]
#  [2000]
#  [2500]
#  [3000]
#  [3200]
#  [4000]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data ={'House size':[1200,1500,1800,2000,2500],
      'price':[200000,250000,300000,350000,400000]}

df = pd.DataFrame(data)

x = df['House size'].values.reshape(-1,1)
y = df['price'].values # Target variable

model = LinearRegression()
model.fit(x,y)


predicted_prices = model.predict(x)

plt.scatter(x,y,color='blue',label='actual prices')
plt.plot(x,predicted_prices,color="blue",label="predicted prices")
plt.xlabel("House size(sq ft)")
plt.ylabel("price")
plt.show()
