# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
data = {
    'Customer':['A','B','C','D','E','F'],
    'Income':[15,16,25,45,60,85],
    'Spending Score':[39,81,6,70,77,15]

}

df = pd.DataFrame(data)
x = df[['Income','Spending Score']]
kmeans = KMeans(n_cluster=2,random_state=42)
df['Cluster'] = kmeans.fit_predict(x)
plt.figure(figsize=(8,5))
colors=['red','green']
for clsuter in range(2):
    cluster_data=df[df['Cluster']==cluster]
    plt.scatter(cluster_data['Income'],cluste_data['Spending Score'],
               color=colors[cluster],label=f"Cluster{cluster}")


centroids = kmeans.cluster_centers_
plt.scatter(centroids[:,0],centroids[:,1],color='blue',marker='X',s=200,label='Centroids')
plt.title("Customer segementation using Kmeans")
plt.xlabel('Annual Income(k$)')
plt.ylabel("Spending Score")
plt.legend()
